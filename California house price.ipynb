# %%
import numpy as np 
import pandas as pd

# %%
dataset = pd.read_csv('housing.csv')

# %%
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
dataset.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# ...

# %%
len(dataset)
# Out:
# 20640

# %%
dataset.corr()
# Out:
# C:\Users\nazish\AppData\Local\Temp\ipykernel_14072\2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
scatter_matrix(dataset,figsize=(12,8))
plt.show()

# %%
dataset.hist(bins = 50,figsize = (20,15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(dataset, test_size = 0.2, shuffle = True, random_state = 33)

# %%
train.shape
# Out:
# (16512, 10)

# %%
train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3578     -118.53     34.24                  24         2718           719.0
# 11132    -117.93     33.85                  25         1026           288.0
# 14862    -117.09     32.65                  25         3509           985.0
# 4929     -118.24     33.99                  41         1425           372.0
# 7805     -118.09     33.89                  42         1150           215.0
#
#        population  households  median_income ocean_proximity  \
# 3578         3018         644         2.9076       <1H OCEAN
# 11132        1646         283         4.2019       <1H OCEAN
# 14862        2359         899         2.6296      NEAR OCEAN
# 4929         1803         353         1.6731       <1H OCEAN
# 7805          708         204         3.6875       <1H OCEAN
#
#        median_house_value
# 3578               275300
# 11132              163900
# 14862              150000
# 4929                88200
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 3578 to 2439
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16512 non-null  float64
#  1   latitude            16512 non-null  float64
#  2   housing_median_age  16512 non-null  int64
#  3   total_rooms         16512 non-null  int64
#  4   total_bedrooms      16352 non-null  float64
#  5   population          16512 non-null  int64
#  6   households          16512 non-null  int64
#  7   median_income       16512 non-null  float64
#  8   ocean_proximity     16512 non-null  object
#  9   median_house_value  16512 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128 entries, 10773 to 2384
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           4128 non-null   float64
#  1   latitude            4128 non-null   float64
#  2   housing_median_age  4128 non-null   int64
#  3   total_rooms         4128 non-null   int64
#  4   total_bedrooms      4081 non-null   float64
#  5   population          4128 non-null   int64
#  6   households          4128 non-null   int64
#  7   median_income       4128 non-null   float64
#  8   ocean_proximity     4128 non-null   object
#  9   median_house_value  4128 non-null   int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 354.8+ KB

# %%
test.shape
# Out:
# (4128, 10)

# %%
test.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10773    -117.90     33.65                  27         3310           598.0
# 2552     -124.17     40.77                  30         1895           366.0
# 1731     -122.34     37.97                  19          392           109.0
# 6342     -117.75     34.06                  52         1171           318.0
# 8912     -118.49     34.02                  30         2075           687.0
#
#        population  households  median_income ocean_proximity  \
# 10773        1402         563         6.6320       <1H OCEAN
# 2552          990         359         2.2227      NEAR OCEAN
# 1731          287          81         6.0426        NEAR BAY
# 6342         1126         276         1.9762          INLAND
# 8912         1026         592         3.1635       <1H OCEAN
#
#        median_house_value
# 10773              441100
# 2552                81300
# 1731               110000
# 6342               105800
# ...

# %%
train_copy = train.copy()

# %%
train_copy.plot(kind = 'scatter', x= 'longitude',y = 'latitude',alpha = 0.3)
plt.show()

# %%
train_x = train_copy.drop('median_house_value',axis = 1)
train_y = train_copy['median_house_value'].copy()

# %%
train_x.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3578     -118.53     34.24                  24         2718           719.0
# 11132    -117.93     33.85                  25         1026           288.0
# 14862    -117.09     32.65                  25         3509           985.0
# 4929     -118.24     33.99                  41         1425           372.0
# 7805     -118.09     33.89                  42         1150           215.0
#
#        population  households  median_income ocean_proximity
# 3578         3018         644         2.9076       <1H OCEAN
# 11132        1646         283         4.2019       <1H OCEAN
# 14862        2359         899         2.6296      NEAR OCEAN
# 4929         1803         353         1.6731       <1H OCEAN
# 7805          708         204         3.6875       <1H OCEAN

# %%
train_y.head()
# Out:
# 3578     275300
# 11132    163900
# 14862    150000
# 4929      88200
# 7805     171500
# Name: median_house_value, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = 'median')
train_x_num = train_x.drop('ocean_proximity', axis = 1)
train_x_cat = train_x['ocean_proximity'].copy()
imputer.fit(train_x_num)
# Out:
# SimpleImputer(strategy='median')

# %%
train_x_num = imputer.transform(train_x_num)

# %%
train_x_num
# Out:
# array([[-1.1853e+02,  3.4240e+01,  2.4000e+01, ...,  3.0180e+03,
#          6.4400e+02,  2.9076e+00],
#        [-1.1793e+02,  3.3850e+01,  2.5000e+01, ...,  1.6460e+03,
#          2.8300e+02,  4.2019e+00],
#        [-1.1709e+02,  3.2650e+01,  2.5000e+01, ...,  2.3590e+03,
#          8.9900e+02,  2.6296e+00],
#        ...,
#        [-1.2206e+02,  3.7710e+01,  3.6000e+01, ...,  1.4780e+03,
#          5.2900e+02,  4.6350e+00],
#        [-1.1831e+02,  3.4180e+01,  1.1000e+01, ...,  1.7000e+03,
#          8.5100e+02,  3.1587e+00],
#        [-1.1961e+02,  3.6590e+01,  1.0000e+01, ...,  1.4430e+03,
#          5.7600e+02,  2.2727e+00]])

# %%
pd.DataFrame(train_x_num)
# Out:
#             0      1     2       3      4       5      6       7
# 0     -118.53  34.24  24.0  2718.0  719.0  3018.0  644.0  2.9076
# 1     -117.93  33.85  25.0  1026.0  288.0  1646.0  283.0  4.2019
# 2     -117.09  32.65  25.0  3509.0  985.0  2359.0  899.0  2.6296
# 3     -118.24  33.99  41.0  1425.0  372.0  1803.0  353.0  1.6731
# 4     -118.09  33.89  42.0  1150.0  215.0   708.0  204.0  3.6875
# ...       ...    ...   ...     ...    ...     ...    ...     ...
# 16507 -117.62  33.43  23.0  4052.0  955.0  1950.0  859.0  4.0647
# 16508 -122.28  37.82  52.0  1489.0  335.0   728.0  244.0  0.8172
# 16509 -122.06  37.71  36.0  3541.0  570.0  1478.0  529.0  4.6350
# 16510 -118.31  34.18  11.0  3112.0  890.0  1700.0  851.0  3.1587
# 16511 -119.61  36.59  10.0  2842.0  620.0  1443.0  576.0  2.2727
#
# [16512 rows x 8 columns]

# %%
type(train_x_num)
# Out:
# numpy.ndarray

# %%
imputer.statistics_.shape
# Out:
# (8,)

# %%
train_x_cat
# Out:
# 3578      <1H OCEAN
# 11132     <1H OCEAN
# 14862    NEAR OCEAN
# 4929      <1H OCEAN
# 7805      <1H OCEAN
#             ...
# 10435    NEAR OCEAN
# 57         NEAR BAY
# 578        NEAR BAY
# 5848      <1H OCEAN
# 2439         INLAND
# Name: ocean_proximity, Length: 16512, dtype: object

# %%
cat = train_x_cat.copy()

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
cat = encoder.fit_transform([cat])
type(cat)
# Out:
# numpy.ndarray

# %%
cat
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
encoder.categories_
# Out:
# [array(['<1H OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['NEAR OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['NEAR OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['NEAR OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['NEAR BAY'], dtype=object),
#  array(['NEAR OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['NEAR BAY'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
#  array(['INLAND'], dtype=object),
#  array(['<1H OCEAN'], dtype=object),
# ...

# %%
one = train_x_cat.copy()
from sklearn.preprocessing import OneHotEncoder
one_hot = OneHotEncoder()
one =one_hot.fit_transform([one])

# %%
one
# Out:
# <1x16512 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %%
train_x_num
# Out:
# array([[-1.1853e+02,  3.4240e+01,  2.4000e+01, ...,  3.0180e+03,
#          6.4400e+02,  2.9076e+00],
#        [-1.1793e+02,  3.3850e+01,  2.5000e+01, ...,  1.6460e+03,
#          2.8300e+02,  4.2019e+00],
#        [-1.1709e+02,  3.2650e+01,  2.5000e+01, ...,  2.3590e+03,
#          8.9900e+02,  2.6296e+00],
#        ...,
#        [-1.2206e+02,  3.7710e+01,  3.6000e+01, ...,  1.4780e+03,
#          5.2900e+02,  4.6350e+00],
#        [-1.1831e+02,  3.4180e+01,  1.1000e+01, ...,  1.7000e+03,
#          8.5100e+02,  3.1587e+00],
#        [-1.1961e+02,  3.6590e+01,  1.0000e+01, ...,  1.4430e+03,
#          5.7600e+02,  2.2727e+00]])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train_scaled = scaler.fit_transform(train_x_num)
train_scaled
# Out:
# array([[ 0.51733492, -0.64983469, -0.37342281, ...,  1.41251455,
#          0.37133525, -0.50716433],
#        [ 0.81770726, -0.8329497 , -0.29418414, ...,  0.19270274,
#         -0.56443888,  0.18343798],
#        [ 1.23822855, -1.39638052, -0.29418414, ...,  0.82661369,
#          1.03233913, -0.65549737],
#        ...,
#        [-1.24985573,  0.97941942,  0.57744129, ...,  0.04333802,
#          0.07323546,  0.41452804],
#        [ 0.62747144, -0.67800623, -1.40352559, ...,  0.24071282,
#          0.90791487, -0.37318439],
#        [-0.02333531,  0.45355066, -1.48276426, ...,  0.01222038,
#          0.19506754, -0.84592923]])

# %%
from sklearn.pipeline import pipeline
num_pipeline = pipeline([
        ('imputer',SimpleImputer(strategy = 'median')),
         ('scaler',StandardScaler())
        )]
# Out:
#   Cell In[40], line 5
#     )]
#     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '[' on line 2

# %%
from sklearn.pipeline import Pipeline
num_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy = 'median')),
    ('scaler',StandardScaler())
])

# %%
train_x_num = train_x.drop('ocean_proximity',axis = 1)
train_x_cat = train_x['ocean_proximity'].copy()

# %%
train_x_num.head()

# %%
train_x_pipeline = num_pipeline.fit_transform(train_x_num)
train_x_pipeline

# %%
num_columns = list(train_x_num)
num_columns

# %%
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([
    ('imputer',SimpleImputer(strategy = 'median'), num_columns),
    ('scaler',StandardScaler(),num_columns),
    ('cat',OneHotEncoder(),cat_cols)
])

# %%
train_x

# %%
train_x_pro = ct.fit_transform(train_x)

# %%
train_x_pro[1]

# %%
pd.DataFrame(train_x_pro)

# %%
train_y

# %% [markdown]
# # train the model
# # RMSE(root meean square error)

# %%
from sklearn.linear_model import LinearRegression

# %%
Ir = LinearRegression()

# %%
Ir.fit(train_x_pro,train_y)

# %%
predictions = Ir.predict(train_x_pro)

# %%
predictions[0],train_y[0]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(train_y,predictions)
print(np.sqrt(mse))

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()
dt.fit(train_x_pro,train_y)

# %%
mse = mean_squared_error(train_y,dt.predict(train_x_pro))
print(np.sqrt(mse))

# %%
from sklearn.model_selection import cross_val_score
result = cross_val_score(dt,train_x_pro,train_y,scoring = 'neg_mean_squared_error',cv = 10)

# %%
result

# %%
print(np.sqrt(scores))

# %%
import numpy as np

# Replace 'scores' with the expression you want to calculate the square root of
result = np.sqrt(scores)

# Now you can print the result
print(result)

# %%
rmse = np.sqrt(scores)
